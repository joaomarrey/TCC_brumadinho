# %%
import pandas as pd

# %%
df = pd.read_csv("./Data/dados_municipais_sal_emprego_rais_1985_2022.csv")
df = df[(df["ano"]>=2015) & (df["ano"]<=2022)]
df
# Out:
#         ano  id_municipio  avg_wage_dec  n_employ_dec
# 0      2022     1707306.0   1133.607298          1559
# 1      2022     1703883.0   1224.761455           301
# 2      2022     1717008.0   1666.783218           360
# 3      2022     1718808.0   1332.218031           187
# 4      2022     2207355.0    585.993449           299
# ...     ...           ...           ...           ...
# 44557  2015     3145307.0    891.652664          1401
# 44558  2015     3163102.0    872.894545           669
# 44559  2015     3169505.0    749.211631           394
# 44560  2015     3300951.0   1233.938041          3550
# 44561  2015     3303203.0   1119.338298         19797
#
# [44562 rows x 4 columns]

# %%
pop = pd.read_csv("./Data/codigos_pop_municipios.csv")
pop = pop.rename({" CODIGO RAIS ": "id_municipio", ' POPULAÇÃO ESTIMADA ': "pop", "NOME DO MUNICÍPIO": "nome"}, axis=1)
pop
# Out:
#       UF  COD. UF  COD. MUNIC                   nome        pop  id_municipio
# 0     RO       11          15  Alta Floresta D'Oeste     22,516       1100015
# 1     RO       11          23              Ariquemes    111,148       1100023
# 2     RO       11          31                 Cabixi      5,067       1100031
# 3     RO       11          49                 Cacoal     86,416       1100049
# 4     RO       11          56             Cerejeiras     16,088       1100056
# ...   ..      ...         ...                    ...        ...           ...
# 5565  GO       52       22005             Vianópolis     14,088       5222005
# 5566  GO       52       22054         Vicentinópolis      9,002       5222054
# 5567  GO       52       22203               Vila Boa      6,451       5222203
# 5568  GO       52       22302          Vila Propício      5,941       5222302
# 5569  DF       53         108               Brasília  3,094,325       5300108
#
# [5570 rows x 6 columns]

# %%
df = pd.merge(df, pop.loc[:, ["id_municipio", "pop", "nome"]], how="left", on=["id_municipio"])
df
# Out:
#         ano  id_municipio  avg_wage_dec  n_employ_dec      pop  \
# 0      2022     1707306.0   1133.607298          1559    4,686
# 1      2022     1703883.0   1224.761455           301    2,627
# 2      2022     1717008.0   1666.783218           360    4,414
# 3      2022     1718808.0   1332.218031           187    4,876
# 4      2022     2207355.0    585.993449           299    3,416
# ...     ...           ...           ...           ...      ...
# 44557  2015     3145307.0    891.652664          1401   31,339
# 44558  2015     3163102.0    872.894545           669    5,151
# 44559  2015     3169505.0    749.211631           394    6,797
# 44560  2015     3300951.0   1233.938041          3550    8,590
# 44561  2015     3303203.0   1119.338298         19797  162,893
#
#                             nome
# 0                          Dueré
# 1                    Carmolândia
# 2         Pindorama do Tocantins
# 3                        Sampaio
# 4                 Pajeú do Piauí
# ...                          ...
# 44557              Novo Cruzeiro
# 44558       São José da Varginha
# 44559                Tumiritinga
# 44560  Comendador Levy Gasparian
# 44561                  Nilópolis
#
# [44562 rows x 6 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#         ano  id_municipio  avg_wage_dec  n_employ_dec      pop  \
# 0      2022     1707306.0   1133.607298          1559    4,686
# 1      2022     1703883.0   1224.761455           301    2,627
# 2      2022     1717008.0   1666.783218           360    4,414
# 3      2022     1718808.0   1332.218031           187    4,876
# 4      2022     2207355.0    585.993449           299    3,416
# ...     ...           ...           ...           ...      ...
# 44557  2015     3145307.0    891.652664          1401   31,339
# 44558  2015     3163102.0    872.894545           669    5,151
# 44559  2015     3169505.0    749.211631           394    6,797
# 44560  2015     3300951.0   1233.938041          3550    8,590
# 44561  2015     3303203.0   1119.338298         19797  162,893
#
#                             nome
# 0                          Dueré
# 1                    Carmolândia
# 2         Pindorama do Tocantins
# 3                        Sampaio
# 4                 Pajeú do Piauí
# ...                          ...
# 44557              Novo Cruzeiro
# 44558       São José da Varginha
# 44559                Tumiritinga
# 44560  Comendador Levy Gasparian
# 44561                  Nilópolis
#
# [44560 rows x 6 columns]

# %%
# df["pop"] = df["pop"].astype("string").map(lambda x:  x[:x.index("(")].replace(".", "") if "." in x else x.replace(",", "")).astype("int")
# df

# %%
# matching brumadinho
treated = [3109006, 3106705
            , 3162922, 3130101 ,3140159
            , 3136652, 3126000, 3147105, 3124104, 3163102, 3149606, 3126406, 3139706, 3146909, 3147402, 3152006
           ]

df_brum = df[df["id_municipio"].isin([
    #3109006, 3118007, 3131901, 3133758, 3145901, 3151107 # brumad
                                   #,
                                   #3106705, 3131307, 3136207, 3118601, 3168705, 3171204 # Betim
                                    # , 3162922, 3110509, 3142205, 3147303, 3151404, 3155801 # sao joaquim de bicas
                                     #, 3130101, 3110509, 3113206, 3171006, 3151404, 3147303 # Igarapé
                                     #,3140159, 3155405, 3151008, 3154101, 3120805, 3169208 # mário campos

                                    # , 
                                    3136652, 3106002, 3165537, 3158953, 3154804, 3145901 # juatuba
                                     , 3126000, 3165404, 3164407, 3155306, 3154200, 3122900 # florestal
                                     , 3147105, 3164704, 3101607, 3138203, 3133808, 3107406 # pará de minas
                                     , 3124104, 3135100, 3131208, 3113305, 3121605, 3140159 # esmeraldas
                                     , 3163102, 3131406, 3135902, 3164308, 3163904, 3130002 # sao jose da varginha
                                     , 3149606, 3129905, 3138708, 3114709, 3125200, 3145505 # pequi
                                     , 3126406, 3138302, 3106101, 3115904, 3145505, 3167905 # fortuna de minas
                                     , 3139706, 3131000, 3152907, 3162203, 3166907, 3152600 # maravilhas
                                     , 3146909, 3102308, 3120805, 3142205, 3169000, 3152709 # papagaios
                                     , 3147402, 3147303, 3155801, 3110509, 3102308, 3142205 # paraopeba
                                     , 3152006, 3114303, 3123601, 3100203, 3110301, 3162005 # pompeu
                                     , 3120904, 3138401, 3139003, 3145604, 3123601, 3137809 # Curvelo
                                   ])]
df_brum
# Out:
#         ano  id_municipio  avg_wage_dec  n_employ_dec     pop  \
# 110    2022     3140159.0   1131.711248          2103  15,814
# 112    2022     3136652.0   1953.283686          9247  27,823
# 113    2022     3163904.0   1677.193381           604   4,563
# 446    2022     3155801.0   2044.538924          3597  18,007
# 448    2022     3145505.0   1885.092547           400   2,829
# ...     ...           ...           ...           ...     ...
# 44022  2015     3114709.0   1095.590367           430   3,614
# 44265  2015     3165404.0    972.466135          1118   7,045
# 44438  2015     3123601.0    985.939248          4909  28,556
# 44501  2015     3158953.0   1105.667215          4843  36,048
# 44558  2015     3163102.0    872.894545           669   5,151
#
#                        nome
# 110            Mário Campos
# 112                 Juatuba
# 113      São Pedro da União
# 446               Rio Pomba
# 448         Olímpio Noronha
# ...                     ...
# 44022         Carvalhópolis
# 44265         Sapucaí-Mirim
# 44438           Elói Mendes
# 44501    Santana do Paraíso
# 44558  São José da Varginha
#
# [544 rows x 6 columns]

# %%
df_brum["treated_group"] = 0
df_brum.loc[df["id_municipio"].isin(treated), "treated_group"] = 1
# Out:
# C:\Users\joaom\AppData\Local\Temp\ipykernel_23588\727530500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brum["treated_group"] = 0

# %%
df_brum["treated_group"]
# Out:
# 110      1
# 112      1
# 113      0
# 446      0
# 448      0
#         ..
# 44022    0
# 44265    0
# 44438    0
# 44501    0
# 44558    1
# Name: treated_group, Length: 544, dtype: int64

# %%
df_brum["treated_after_treatment"] = 0
df_brum.loc[(df_brum["treated_group"]) & (df_brum["ano"] >= 2019), "treated_after_treatment"] = 1
# Out:
# C:\Users\joaom\AppData\Local\Temp\ipykernel_23588\1647316685.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brum["treated_after_treatment"] = 0

# %%
df_brum["treated_after_treatment"]
# Out:
# 110      1
# 112      1
# 113      0
# 446      0
# 448      0
#         ..
# 44022    0
# 44265    0
# 44438    0
# 44501    0
# 44558    0
# Name: treated_after_treatment, Length: 544, dtype: int64

# %%
df_brum.to_csv("./Data/matching_nocov_brum_group_3.csv", index=False)
