# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("./Data/dados_municipais_sal_emprego_rais_1985_2022.csv")
df
# Out:
#          ano  id_municipio  avg_wage_dec  n_employ_dec
# 0       2022     1707306.0   1133.607298          1559
# 1       2022     1703883.0   1224.761455           301
# 2       2022     1717008.0   1666.783218           360
# 3       2022     1718808.0   1332.218031           187
# 4       2022     2207355.0    585.993449           299
# ...      ...           ...           ...           ...
# 196508  1985     3546900.0           NaN           178
# 196509  1985     3542602.0           NaN          4366
# 196510  1985     3542008.0           NaN           262
# 196511  1985     3527603.0           NaN           908
# 196512  1985     3510302.0           NaN          1188
#
# [196513 rows x 4 columns]

# %%
pop = pd.read_csv("./Data/codigos_pop_municipios.csv")
pop = pop.rename({" CODIGO RAIS ": "id_municipio", ' POPULAÇÃO ESTIMADA ': "pop", "NOME DO MUNICÍPIO": "nome"}, axis=1)
pop
# Out:
#       UF  COD. UF  COD. MUNIC                   nome        pop  id_municipio
# 0     RO       11          15  Alta Floresta D'Oeste     22,516       1100015
# 1     RO       11          23              Ariquemes    111,148       1100023
# 2     RO       11          31                 Cabixi      5,067       1100031
# 3     RO       11          49                 Cacoal     86,416       1100049
# 4     RO       11          56             Cerejeiras     16,088       1100056
# ...   ..      ...         ...                    ...        ...           ...
# 5565  GO       52       22005             Vianópolis     14,088       5222005
# 5566  GO       52       22054         Vicentinópolis      9,002       5222054
# 5567  GO       52       22203               Vila Boa      6,451       5222203
# 5568  GO       52       22302          Vila Propício      5,941       5222302
# 5569  DF       53         108               Brasília  3,094,325       5300108
#
# [5570 rows x 6 columns]

# %%
df = pd.merge(df, pop.loc[:, ["id_municipio", "pop", "nome"]], how="left", on="id_municipio")
df
# Out:
#          ano  id_municipio  avg_wage_dec  n_employ_dec     pop  \
# 0       2022     1707306.0   1133.607298          1559   4,686
# 1       2022     1703883.0   1224.761455           301   2,627
# 2       2022     1717008.0   1666.783218           360   4,414
# 3       2022     1718808.0   1332.218031           187   4,876
# 4       2022     2207355.0    585.993449           299   3,416
# ...      ...           ...           ...           ...     ...
# 196508  1985     3546900.0           NaN           178   8,889
# 196509  1985     3542602.0           NaN          4366  56,463
# 196510  1985     3542008.0           NaN           262   6,736
# 196511  1985     3527603.0           NaN           908  15,628
# 196512  1985     3510302.0           NaN          1188  21,257
#
#                           nome
# 0                        Dueré
# 1                  Carmolândia
# 2       Pindorama do Tocantins
# 3                      Sampaio
# 4               Pajeú do Piauí
# ...

# %%
df.dropna(inplace=True)

# %%
df["pop"] = df["pop"].astype("string").map(lambda x:  x[:x.index("(")].replace(".", "") if "." in x else x.replace(",", "")).astype("int")

# %%
df
# Out:
#          ano  id_municipio  avg_wage_dec  n_employ_dec     pop  \
# 0       2022     1707306.0   1133.607298          1559    4686
# 1       2022     1703883.0   1224.761455           301    2627
# 2       2022     1717008.0   1666.783218           360    4414
# 3       2022     1718808.0   1332.218031           187    4876
# 4       2022     2207355.0    585.993449           299    3416
# ...      ...           ...           ...           ...     ...
# 133335  1999     3171303.0    241.960520          8336   79910
# 133336  1999     3505708.0    660.058610        116708  279704
# 133337  1999     3506003.0    510.019284         60264  381706
# 133338  1999     3529609.0    286.124795           396    3813
# 133339  1999     3542206.0    342.579227          3916   29743
#
#                           nome
# 0                        Dueré
# 1                  Carmolândia
# 2       Pindorama do Tocantins
# 3                      Sampaio
# 4               Pajeú do Piauí
# ...

# %%
df["tx_employ"] = df["n_employ_dec"] / df["pop"]
df
# Out:
#          ano  id_municipio  avg_wage_dec  n_employ_dec     pop  \
# 0       2022     1707306.0   1133.607298          1559    4686
# 1       2022     1703883.0   1224.761455           301    2627
# 2       2022     1717008.0   1666.783218           360    4414
# 3       2022     1718808.0   1332.218031           187    4876
# 4       2022     2207355.0    585.993449           299    3416
# ...      ...           ...           ...           ...     ...
# 133335  1999     3171303.0    241.960520          8336   79910
# 133336  1999     3505708.0    660.058610        116708  279704
# 133337  1999     3506003.0    510.019284         60264  381706
# 133338  1999     3529609.0    286.124795           396    3813
# 133339  1999     3542206.0    342.579227          3916   29743
#
#                           nome  tx_employ
# 0                        Dueré   0.332693
# 1                  Carmolândia   0.114579
# 2       Pindorama do Tocantins   0.081559
# ...

# %%
df1 = df[df["id_municipio"].isin([3107307, 3107406, 3111200, 3118007, 3126109, 3127107, 3128709, 3131901, 3135209, 3137205, 3137601, 3138401, 3140001, 3149309,
                                  3151206, 3152105, 3161106, 3169406])]
df1
# Out:
#          ano  id_municipio  avg_wage_dec  n_employ_dec    pop           nome  \
# 605     2022     3151206.0   1680.052439         15665  56845       Pirapora
# 1402    2022     3135209.0   1346.143045          5931  67958       Januária
# 1442    2022     3111200.0   1311.470226         12912  54338     Campo Belo
# 1991    2022     3128709.0   1712.500286         15006  52234        Guaxupé
# 2035    2022     3161106.0   1508.297111          4841  56625  São Francisco
# ...      ...           ...           ...           ...    ...            ...
# 131853  1999     3140001.0    476.162543          4902  61830        Mariana
# 132373  1999     3169406.0    150.237401          8733  57127    Três Pontas
# 132834  1999     3128709.0    215.820058          9679  52234        Guaxupé
# 132835  1999     3138401.0    240.592544          7218  52690     Leopoldina
# 133237  1999     3127107.0    240.869770          5488  60508         Frutal
#
#         tx_employ
# 605      0.275574
# ...

# %%
mariana = df[df["id_municipio"] == 3140001]

# %%
fig = px.line(df1, x="ano", y="avg_wage_dec", color='nome')
fig.show()

# %%
fig = px.line(df1, x="ano", y="tx_employ", color='nome')
fig.show()

# %%
fig = px.line(mariana, x="ano", y="avg_wage_dec")
fig.show()

# %%
fig = px.line(df1, x="ano", y="n_employ_dec", color='nome')
fig.show()

# %%
fig = px.line(mariana, x="ano", y="n_employ_dec")
fig.show()

# %%
df2 = df[df["id_municipio"].isin([3127107, 3137601, 3140001, 3149309, 3151206, 3152105, 3169406])]
df2
# Out:
#          ano  id_municipio  avg_wage_dec  n_employ_dec    pop            nome  \
# 605     2022     3151206.0   1680.052439         15665  56845        Pirapora
# 2325    2022     3140001.0   1897.358329         20961  61830         Mariana
# 2437    2022     3152105.0   1565.173507         18254  60003      Ponte Nova
# 2511    2022     3127107.0   1668.598470         15457  60508          Frutal
# 3373    2022     3149309.0   1607.188881         16111  65149  Pedro Leopoldo
# ...      ...           ...           ...           ...    ...             ...
# 130191  1999     3137601.0    339.300412          4077  66744     Lagoa Santa
# 131021  1999     3151206.0    306.651267          6980  56845        Pirapora
# 131853  1999     3140001.0    476.162543          4902  61830         Mariana
# 132373  1999     3169406.0    150.237401          8733  57127     Três Pontas
# 133237  1999     3127107.0    240.869770          5488  60508          Frutal
#
#         tx_employ
# ...

# %%
fig = px.line(df2, x="ano", y="avg_wage_dec", color='nome')
fig.show()

# %%
fig = px.line(df2, x="ano", y="n_employ_dec", color='nome')
fig.show()

# %%
# df = pd.read_csv("./Data/dados_municipais_sal_emprego_rais_1985_2022.csv")
# df

# %%
df3 = df[df["id_municipio"].isin([3101706, 3102605, 3104205, 3107109, 3109006, 3134400, 3135050, 3139003, 3144300, 3145604, 3145901, 3157005, 3170800])]
df3
# Out:
#          ano  id_municipio  avg_wage_dec  n_employ_dec    pop  \
# 197     2022     3134400.0   1722.835602         12340  40101
# 820     2022     3104205.0   1509.438863         13281  40658
# 919     2022     3145604.0   1462.314061         10463  41987
# 1136    2022     3157005.0   1365.104378          7044  41864
# 1584    2022     3139003.0   1464.525799         10258  42682
# ...      ...           ...           ...           ...    ...
# 130107  1999     3102605.0    379.523587          5492  41704
# 130383  1999     3109006.0    389.781240          3506  41208
# 130494  1999     3145604.0    224.501453          4527  41987
# 131699  1999     3101706.0    275.242121          2000  42380
# 133082  1999     3170800.0    263.678066          3728  40101
#
#                    nome  tx_employ
# 197             Iturama   0.307723
# 820               Arcos   0.326652
# 919            Oliveira   0.249196
# 1136            Salinas   0.168259
# 1584            Machado   0.240336
# ...

# %%
fig = px.line(df3, x="ano", y="avg_wage_dec", color='nome')
fig.show()

# %%
fig = px.line(df3, x="ano", y="tx_employ", color='nome')
fig.show()

# %%
fig = px.line(df3, x="ano", y="n_employ_dec", color='nome')
fig.show()

# %%
#################################################

# %%
# matching brumadinho
treated = [3109006, 3106705
        #    , 3162922, 3130101
        #    , 3136652, 3126000, 3147105, 3124104, 3163102, 3149606, 3126406, 3139706, 3146909, 3147402, 3152006
           ]

df4 = df[df["id_municipio"].isin([3109006, 3118007, 3131901, 3133758, 3145901, 3151107 # brumad
                                   ,3106705, 3131307, 3136207, 3118601, 3168705, 3171204 # Betim
                                #     , 3162922, 3110509, 3142205, 3147303, 3151404, 3155801 # sao joaquim de bicas
                                #     , 3130101, 3110509, 3113206, 3171006, 3151404, 3147303 # Igarapé

                                    # , 3136652, 3106002, 3165537, 3158953, 3154804, 3145901 # juatuba
                                    # , 3126000, 3165404, 3164407, 3155306, 3154200, 3122900 # florestal
                                    # , 3147105, 3164704, 3101607, 3138203, 3133808, 3107406 # pará de minas
                                    # , 3124104, 3135100, 3131208, 3113305, 3121605, 3140159 # esmeraldas
                                    # , 3163102, 3131406, 3135902, 3164308, 3163904, 3130002 # sao jose da varginha
                                    # , 3149606, 3129905, 3138708, 3114709, 3125200, 3145505 # pequi
                                    # , 3126406, 3138302, 3106101, 3115904, 3145505, 3167905 # fortuna de minas
                                    # , 3139706, 3131000, 3152907, 3162203, 3166907, 3152600 # maravilhas
                                    # , 3146909, 3102308, 3120805, 3142205, 3169000, 3152709 # papagaios
                                    # , 3147402, 3147303, 3155801, 3110509, 3102308, 3142205 # paraopeba
                                    # , 3152006, 3114303, 3123601, 3100203, 3110301, 3162005 # pompeu
                                   ])]
df4
# Out:
#          ano  id_municipio  avg_wage_dec  n_employ_dec     pop  \
# 323     2022     3136207.0   1660.801087         22676   80903
# 1531    2022     3106705.0   2315.558532        119691  450024
# 1589    2022     3151107.0   1835.976400          2465   10791
# 1936    2022     3145901.0   2594.410801         15052   40220
# 1937    2022     3131307.0   1728.424656         78384  267333
# ...      ...           ...           ...           ...     ...
# 131057  1999     3118007.0    388.133972          4584   55836
# 131107  1999     3118601.0    406.303276        102362  673849
# 132093  1999     3106705.0    632.554876         58266  450024
# 132154  1999     3151107.0    338.980213          1298   10791
# 132526  1999     3136207.0    370.937192         11799   80903
#
#                   nome  tx_employ
# 323     João Monlevade   0.280286
# 1531             Betim   0.265966
# 1589       Pirapetinga   0.228431
# 1936       Ouro Branco   0.374242
# ...

# %%
fig = px.line(df4, x="ano", y="avg_wage_dec", color='nome')
fig.show()

# %%
fig = px.line(df4, x="ano", y="tx_employ", color='nome')
fig.show()

# %%
fig = px.line(df4, x="ano", y="n_employ_dec", color='nome')
fig.show()

# %%
df4["treated_group"] = 0
df4.loc[df["id_municipio"].isin(treated), "treated_group"] = 1
# Out:
# C:\Users\joaom\AppData\Local\Temp\ipykernel_44560\2154877752.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df4["treated_group"]
# Out:
# 323       0
# 1531      1
# 1589      0
# 1936      0
# 1937      0
#          ..
# 131057    0
# 131107    0
# 132093    1
# 132154    0
# 132526    0
# Name: treated_group, Length: 288, dtype: int64

# %%
df4["treated_after_treatment"] = 0
df4.loc[(df4["treated_group"]) & (df4["ano"] >= 2019), "treated_after_treatment"] = 1
# Out:
# C:\Users\joaom\AppData\Local\Temp\ipykernel_44560\2100198677.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df4["treated_after_treatment"]
# Out:
# 323       0
# 1531      1
# 1589      0
# 1936      0
# 1937      0
#          ..
# 131057    0
# 131107    0
# 132093    0
# 132154    0
# 132526    0
# Name: treated_after_treatment, Length: 288, dtype: int64

# %%
df4 = df4[df4["ano"] >= 2015]

# %%
df4.to_csv("./Data/matching_nocov_brum.csv", index=False)
